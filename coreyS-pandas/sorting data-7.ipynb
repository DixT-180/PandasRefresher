# %%
import pandas as pd

# %%
d = {
    'first':['corey','bella','julia'],
    'last' : ['singh','thompson','stephens'],
    'email' : ['schafer@','dabger@','annie@']
}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#    first      last     email
# 0  corey     singh  schafer@
# 1  bella  thompson   dabger@
# 2  julia  stephens    annie@

# %%
#descending order

# %%
df.sort_values(by = 'last', ascending = True)
# Out:
#    first      last     email
# 0  corey     singh  schafer@
# 2  julia  stephens    annie@
# 1  bella  thompson   dabger@

# %%
df['first'].sort_values()
# Out:
# 1    bella
# 0    corey
# 2    julia
# Name: first, dtype: object

# %%
df= pd.read_csv('developer/survey_results_public.csv')
schema_df = pd.read_csv('developer/survey_results_schema.csv',index_col='Column')

# %%
df.sort_values(by = 'Country')
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 61540       62788          I am a developer by profession      Yes   NaN
# 43843       44697          I am a developer by profession      Yes   NaN
# 43709       44556          I am a developer by profession       No   NaN
# 43708       44555          I am a developer by profession       No   NaN
# 43157       43966  I am a student who is learning to code      Yes  25.0
# ...           ...                                     ...      ...   ...
# 64425       60055                                     NaN       No   NaN
# 64431       61121                                     NaN      Yes   NaN
# 64434       61570                                     NaN       No   NaN
# 64436       61918                                     NaN      Yes   NaN
# 64440       62605                                     NaN       No   NaN
#
#       Age1stCode CompFreq  CompTotal  ConvertedComp      Country  \
# ...

# %%
df['Country'].head(10)
# Out:
# 61540    Afghanistan
# 63925    Afghanistan
# 63993    Afghanistan
# 38261    Afghanistan
# 28270    Afghanistan
# 9806     Afghanistan
# 62520    Afghanistan
# 50812    Afghanistan
# 50469    Afghanistan
# 43642    Afghanistan
# Name: Country, dtype: object

# %%
df.sort_values(by=['Country','ConvertedComp'],ascending = [True,False],inplace=True)

# %%
df[['Country','ConvertedComp']] #sorting by alphabetical country and descending salary at same time
# Out:
#            Country  ConvertedComp
# 61540  Afghanistan      1000000.0
# 63925  Afghanistan      1000000.0
# 63993  Afghanistan      1000000.0
# 38261  Afghanistan       231192.0
# 28270  Afghanistan       130000.0
# ...            ...            ...
# 64425          NaN            NaN
# 64431          NaN            NaN
# 64434          NaN            NaN
# 64436          NaN            NaN
# 64440          NaN            NaN
#
# [64461 rows x 2 columns]

# %%
df['ConvertedComp'].nlargest(10) #see top largest 10 salary
# Out:
# 5701     2000000.0
# 53175    2000000.0
# 42657    2000000.0
# 58136    2000000.0
# 45753    2000000.0
# 121      2000000.0
# 123      2000000.0
# 191      2000000.0
# 663      2000000.0
# 697      2000000.0
# Name: ConvertedComp, dtype: float64

# %%
#run this method on Dataframe

# %%
df.nlargest(10,'ConvertedComp') #nsmallest
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 5701         5725                     I am a developer by profession       No
# 53175       54263                     I am a developer by profession      Yes
# 42657       43430                     I am a developer by profession      Yes
# 58136       59279                     I am a developer by profession      Yes
# 45753       46711                     I am a developer by profession      Yes
# 121           123                     I am a developer by profession      Yes
# 123           125  I am not primarily a developer, but I write co...      Yes
# 191           193                     I am a developer by profession      Yes
# 663           665                     I am a developer by profession      Yes
# 697           699  I am not primarily a developer, but I write co...      Yes
#
#         Age            Age1stCode CompFreq     CompTotal  ConvertedComp  \
# ...
