# %%
import pandas as pd

# %%
d = {
    'first':['corey','abella','julia'],
    'last' : ['singh','danger','ann'],
    'email' : ['schafer@','dabger@','annie@']
}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#     first    last     email
# 0   corey   singh  schafer@
# 1  abella  danger   dabger@
# 2   julia     ann    annie@

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
#df1=df.set_index('email',inplace = True)

# %%
df.loc[0]
# Out:
# first       corey
# last        singh
# email    schafer@
# Name: 0, dtype: object

# %%
#df.reset_index(inplace =True)
#df

# %%
df1 = pd.read_csv('developer/survey_results_public.csv')
schema_df = pd.read_csv('developer/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns',40)
pd.set_option('display.max_rows',40)

# %%
df1
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df1 = pd.read_csv('developer/survey_results_public.csv',index_col = 'Respondent')

# %%
df1.loc[1]
# Out:
# MainBranch                     I am a developer by profession
# Hobbyist                                                  Yes
# Age                                                       NaN
# Age1stCode                                                 13
# CompFreq                                              Monthly
#                                        ...
# WebframeWorkedWith                       ASP.NET;ASP.NET Core
# WelcomeChange         Just as welcome now as I felt last year
# WorkWeekHrs                                                50
# YearsCode                                                  36
# YearsCodePro                                               27
# Name: 1, Length: 60, dtype: object

# %%
schema_df = pd.read_csv('developer/survey_results_schema.csv',index_col = 'Column')

# %%
schema_df
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
schema_df.loc['Age']                           #double brac gives dataframe
# Out:
# QuestionText    What is your age (in years)? If you prefer not...
# Name: Age, dtype: object

# %%
schema_df.loc['Age','QuestionText']
# Out:
# 'What is your age (in years)? If you prefer not to answer, you may leave this question blank.'

# %%
schema_df.sort_index() # arg  ascending = False
# Out:
#                                                          QuestionText
# Column
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# CompFreq             Is that compensation weekly, monthly, or yearly?
# CompTotal           What is your current total compensation (salar...
# ConvertedComp       Salary converted to annual USD salaries using ...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
#schema_df.sort_index(inplace = True) #for permanent ascending order
