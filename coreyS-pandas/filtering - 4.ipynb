# %%
import pandas as pd

# %%
df= pd.read_csv('developer/survey_results_public.csv')
schema_df = pd.read_csv('developer/survey_results_schema.csv',index_col='Column')

# %%
schema_df
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
schema_df.loc['ConvertedComp']['QuestionText']
# Out:
# 'Salary converted to annual USD salaries using the exchange rate on 2020-02-19, assuming 12 working months and 50 working weeks.'

# %%
df['ConvertedComp'] >2000
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 64456    False
# 64457    False
# 64458    False
# 64459    False
# 64460    False
# Name: ConvertedComp, Length: 64461, dtype: bool

# %%
High_salary = (df['ConvertedComp'] >200000) # highsalary is a filter for filtering convertedcomp above 200000

# %%
df.loc[High_salary] #df.[High_salary] #put filter into dataframe
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 17             18  I am a developer by profession      Yes  32.0         12
# 56             57  I am a developer by profession       No  44.0         12
# 64             65  I am a developer by profession      Yes  34.0         13
# 66             67  I am a developer by profession      Yes  35.0          6
# 68             69  I am a developer by profession      Yes  25.0         12
# ...           ...                             ...      ...   ...        ...
# 64014       65477  I am a developer by profession      Yes   NaN         13
# 64035       65502  I am a developer by profession      Yes   NaN         11
# 64057       65527  I am a developer by profession      Yes   NaN         11
# 64083       65554  I am a developer by profession      Yes   NaN         13
# 64113       65586  I am a developer by profession      Yes   NaN          8
#
# ...

# %%
Age_filter = (df['Age'] < 20 )

# %%
c=df.loc[Age_filter]

# %%
#pd.set_option('display.max_rows', 50000)
#pd.set_option('display.max_columns', 50000) #never in the freaking world try this never!!!

# %%
c =df.loc[High_salary,['Country','LanguageWorkedWith','Age']]

# %%
c
# Out:
#              Country                                 LanguageWorkedWith   Age
# 17     United States                Bash/Shell/PowerShell;HTML/CSS;Perl  32.0
# 56     United States                                             C#;VBA  44.0
# 64     United States   Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;SQL  34.0
# 66     United States                           HTML/CSS;JavaScript;Ruby  35.0
# 68            France                                    HTML/CSS;Python  25.0
# ...              ...                                                ...   ...
# 64014  United States    Bash/Shell/PowerShell;C;C++;Go;Perl;Python;Ruby   NaN
# 64035  United States  C#;HTML/CSS;JavaScript;Perl;Python;SQL;TypeScript   NaN
# 64057  United States  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...   NaN
# 64083  United States                                                NaN   NaN
# 64113  United States                                                NaN   NaN
#
# [2306 rows x 3 columns]

# %%
countries = ['India','Nepal','China'] 
Country_filter = df['Country'].isin(countries )

# %%
df.loc[Country_filter,['Country','Hobbyist','LanguageWorkedWith']]
# Out:
#       Country Hobbyist                     LanguageWorkedWith
# 6       India      Yes                        C#;HTML/CSS;PHP
# 21      India      Yes                            Java;Python
# 27      China      Yes                               Python;R
# 57      India      Yes           C#;JavaScript;SQL;TypeScript
# 62      India      Yes  C;C++;HTML/CSS;Java;JavaScript;Python
# ...       ...      ...                                    ...
# 64398   India      Yes                                    NaN
# 64439   India      Yes                                    NaN
# 64442   India      Yes                                    SQL
# 64448   Nepal      Yes                                    NaN
# 64452   India      Yes                                    NaN
#
# [9016 rows x 3 columns]

# %%
High_salary = (df['Country'] == 'Nepal')
Age_filter_Nepali = (df['Age'] < 26)
xx = df.loc[High_salary,['Age','ConvertedComp','Hobbyist']]
xx
# Out:
#         Age  ConvertedComp Hobbyist
# 171    26.0            NaN      Yes
# 273     NaN            NaN       No
# 621    18.0            NaN      Yes
# 805    34.0         5256.0      Yes
# 1349   26.0         5256.0      Yes
# ...     ...            ...      ...
# 63312  19.0            NaN      Yes
# 63638   NaN            NaN      Yes
# 63736   NaN            NaN      Yes
# 63744   NaN            NaN       No
# 64448   NaN            NaN      Yes
#
# [242 rows x 3 columns]

# %%
agef = (df['Age'])

# %%
df['LanguageWorkedWith']
# Out:
# 0                                   C#;HTML/CSS;JavaScript
# 1                                         JavaScript;Swift
# 2                                 Objective-C;Python;Swift
# 3                                                      NaN
# 4                                        HTML/CSS;Ruby;SQL
#                                ...
# 64456                                                  NaN
# 64457    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                  NaN
# 64459                                             HTML/CSS
# 64460                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 64461, dtype: object

# %%
langfilter = df['LanguageWorkedWith'].str.contains('Python','HTML/CSS',na=False)

# %%
df.loc[langfilter,'LanguageWorkedWith']
# Out:
# 2                                 Objective-C;Python;Swift
# 7                                               Python;SQL
# 9                      HTML/CSS;Java;JavaScript;Python;SQL
# 12                                     C;JavaScript;Python
# 14        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 64433    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 64438       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 64443              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 64446    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64457    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object

# %%
Mero_desh = (df['Country'] == 'Nepal')
#Age_filter_Nepali = (df['Age'] < 26)
xx = df.loc[Mero_desh,['Age','ConvertedComp','Hobbyist','UndergradMajor']]
xx
# Out:
#         Age  ConvertedComp Hobbyist  \
# 171    26.0            NaN      Yes
# 273     NaN            NaN       No
# 621    18.0            NaN      Yes
# 805    34.0         5256.0      Yes
# 1349   26.0         5256.0      Yes
# ...     ...            ...      ...
# 63312  19.0            NaN      Yes
# 63638   NaN            NaN      Yes
# 63736   NaN            NaN      Yes
# 63744   NaN            NaN       No
# 64448   NaN            NaN      Yes
#
#                                           UndergradMajor
# 171    Computer science, computer engineering, or sof...
# 273    Computer science, computer engineering, or sof...
# 621                                                  NaN
# 805    A business discipline (such as accounting, fin...
# 1349   Computer science, computer engineering, or sof...
# ...                                                  ...
# 63312  Computer science, computer engineering, or sof...
# 63638  Computer science, computer engineering, or sof...
# ...

# %%
sal_non_zero = (xx['ConvertedComp']>0)
xy = xx.loc[sal_non_zero,['Age','ConvertedComp','Hobbyist','UndergradMajor']]
xy
# Out:
#         Age  ConvertedComp Hobbyist  \
# 805    34.0         5256.0      Yes
# 1349   26.0         5256.0      Yes
# 1813    NaN        18912.0       No
# 5766   30.0        13128.0      Yes
# 5969   24.0         7356.0      Yes
# ...     ...            ...      ...
# 58081  20.0        30000.0      Yes
# 58136   NaN      2000000.0      Yes
# 58186  26.0         6000.0      Yes
# 61635  24.0         2628.0      Yes
# 62413   NaN        12000.0      Yes
#
#                                           UndergradMajor
# 805    A business discipline (such as accounting, fin...
# 1349   Computer science, computer engineering, or sof...
# 1813   Computer science, computer engineering, or sof...
# 5766   Information systems, information technology, o...
# 5969   A business discipline (such as accounting, fin...
# ...                                                  ...
# 58081  Computer science, computer engineering, or sof...
# 58136  Computer science, computer engineering, or sof...
# ...

# %%
xy.count()
# Out:
# Age               66
# ConvertedComp     81
# Hobbyist          81
# UndergradMajor    79
# dtype: int64

# %%
xx.count()
# Out:
# Age               145
# ConvertedComp      82
# Hobbyist          242
# UndergradMajor    198
# dtype: int64
