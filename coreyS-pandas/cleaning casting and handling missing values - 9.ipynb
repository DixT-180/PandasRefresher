# %%
import numpy as np
import pandas as pd

# %%
 people = {
     'first': ['narayan','susma','binod',np.nan,'acharni',None,'NA','mukti'],
     'last': ['dhungana','karki','shrestha',np.nan,'acharya',np.nan,'Missing','dahal'],
     'email': ['np@yahoo','susma@yahoo','binod@yahoo',None,'ach@yahoo',np.nan,'NA','mukti@yahoo'],
     'age':['50','19','25',None,'49',None,'Missing','32']
 }

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#      first      last        email      age
# 0  narayan  dhungana     np@yahoo       50
# 1    susma     karki  susma@yahoo       19
# 2    binod  shrestha  binod@yahoo       25
# 3      NaN       NaN         None     None
# 4  acharni   acharya    ach@yahoo       49
# 5     None       NaN          NaN     None
# 6       NA   Missing           NA  Missing
# 7    mukti     dahal  mukti@yahoo       32

# %%
df.dropna()
# Out:
#      first      last        email      age
# 0  narayan  dhungana     np@yahoo       50
# 1    susma     karki  susma@yahoo       19
# 2    binod  shrestha  binod@yahoo       25
# 4  acharni   acharya    ach@yahoo       49
# 6       NA   Missing           NA  Missing
# 7    mukti     dahal  mukti@yahoo       32

# %%
df.dropna(axis = 'index',how = 'any') #index or columns drop index(row) or columns
# Out:
#      first      last        email      age
# 0  narayan  dhungana     np@yahoo       50
# 1    susma     karki  susma@yahoo       19
# 2    binod  shrestha  binod@yahoo       25
# 4  acharni   acharya    ach@yahoo       49
# 6       NA   Missing           NA  Missing
# 7    mukti     dahal  mukti@yahoo       32

# %%
df.dropna(axis = 'index',how = 'all')
# Out:
#      first      last        email      age
# 0  narayan  dhungana     np@yahoo       50
# 1    susma     karki  susma@yahoo       19
# 2    binod  shrestha  binod@yahoo       25
# 4  acharni   acharya    ach@yahoo       49
# 6       NA   Missing           NA  Missing
# 7    mukti     dahal  mukti@yahoo       32

# %%
 df.dropna(axis = 'columns',how = 'any') #any -- removes if any missing value is present
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6, 7]

# %%
 df.dropna(axis = 'index',how = 'any',subset = ['email'])
# Out:
#      first      last        email      age
# 0  narayan  dhungana     np@yahoo       50
# 1    susma     karki  susma@yahoo       19
# 2    binod  shrestha  binod@yahoo       25
# 4  acharni   acharya    ach@yahoo       49
# 6       NA   Missing           NA  Missing
# 7    mukti     dahal  mukti@yahoo       32

# %%
 df.dropna(axis = 'index',how = 'all',subset = ['last','email'])
# Out:
#      first      last        email      age
# 0  narayan  dhungana     np@yahoo       50
# 1    susma     karki  susma@yahoo       19
# 2    binod  shrestha  binod@yahoo       25
# 4  acharni   acharya    ach@yahoo       49
# 6       NA   Missing           NA  Missing
# 7    mukti     dahal  mukti@yahoo       32

# %%
df = pd.DataFrame(people)
df.replace('NA',np.nan,inplace = True)
df.replace('Missing',np.nan,inplace = True)

# %%
df.isna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a61b34bb9a65> in <module>
# ----> 1 df.isna()
#
# NameError: name 'df' is not defined

# %%
df.fillna('MISSING')
# Out:
#      first      last        email      age
# 0  narayan  dhungana     np@yahoo       50
# 1    susma     karki  susma@yahoo       19
# 2    binod  shrestha  binod@yahoo       25
# 3  MISSING   MISSING      MISSING  MISSING
# 4  acharni   acharya    ach@yahoo       49
# 5  MISSING   MISSING      MISSING  MISSING
# 6  MISSING   MISSING      MISSING  MISSING
# 7    mukti     dahal  mukti@yahoo       32

# %%
df.fillna(0)
# Out:
#      first      last        email age
# 0  narayan  dhungana     np@yahoo  50
# 1    susma     karki  susma@yahoo  19
# 2    binod  shrestha  binod@yahoo  25
# 3        0         0            0   0
# 4  acharni   acharya    ach@yahoo  49
# 5        0         0            0   0
# 6        0         0            0   0
# 7    mukti     dahal  mukti@yahoo  32

# %%
#average age of df

# %%
df.dtypes #object -- string or other stuffs
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
 df['age'].mean() #error cause string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-f9d66468434b> in <module>
# ----> 1 df['age'].mean() #error cause string
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11215             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11216         return self._reduce(
# > 11217             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11218         )
#   11219
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
#    3890             with np.errstate(all="ignore"):
# -> 3891                 return op(delegate, skipna=skipna, **kwds)
#    3892
#    3893         # TODO(EA) dispatch to Index
#
# ...

# %%
type(np.nan)
# Out:
# float

# %%
df=df.fillna('0')
df['age'] = df['age'].astype(int) #casting str into int so we can calculate mean
df['age'].mean()
# Out:
# 21.875

# %%
navalues = ['NA','Missing']
df1= pd.read_csv('developer/survey_results_public.csv',index_col = 'Respondent',navalues )
schema_df = pd.read_csv('developer/survey_results_schema.csv',index_col='Column')
# Out:
#   File "<ipython-input-117-a9c1958109b9>", line 2
#     df1= pd.read_csv('developer/survey_results_public.csv',index_col = 'Respondent',navalues )
#                                                                                    ^
# SyntaxError: positional argument follows keyword argument

# %%
df1.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df1['YearsCode'].head(10)
# Out:
# Respondent
# 1     36
# 2      7
# 3      4
# 4      7
# 5     15
# 6      6
# 7      6
# 8     17
# 9      6
# 10     8
# Name: YearsCode, dtype: object

# %%
#df1['YearsCode']= df1['YearsCode'].astype(float) doesnt work

# %%
df1['YearsCode'].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
df1['YearsCode'].replace('Less than 1 year',0,inplace = True)
df1['YearsCode'].replace('More than 50 years',51,inplace = True)

# %%
df1['YearsCode'].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 0, '3', '13', '25', '16', '43',
#        '11', '38', '33', nan, '24', '21', '12', '40', '27', '50', '46',
#        '14', '18', '28', '32', '44', '26', '42', '31', '34', '29', '1',
#        '39', '41', '45', 51, '47', '49', '48'], dtype=object)

# %%
df1['YearsCode']= df1['YearsCode'].astype(float)

# %%
df1['YearsCode'].mean()
# Out:
# 12.709052770265584
