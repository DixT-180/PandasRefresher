# %%
import pandas as pd

# %%
df= pd.read_csv('developer/survey_results_public.csv',index_col = 'Respondent')
schema_df = pd.read_csv('developer/survey_results_schema.csv',index_col='Column')

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df['ConvertedComp'].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8     116000.0
# 9          NaN
# 10     32315.0
# 11     40070.0
# 12     14268.0
# 13     38916.0
# 14     66000.0
# 15         NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
 df['ConvertedComp'].count() #non nan values
# Out:
# 34756

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df['Hobbyist'].value_counts(normalize=True)*100 #%
# Out:
# Yes    78.222802
# No     21.777198
# Name: Hobbyist, dtype: float64

# %%
schema_df
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
schema_df.loc['OpSys']
# Out:
# QuestionText    What is the primary operating system in which ...
# Name: OpSys, dtype: object

# %%
df['OpSys'].value_counts(normalize=True)*100
# Out:
# Windows        48.321121
# Linux-based    26.556164
# MacOS          25.032013
# BSD             0.090702
# Name: OpSys, dtype: float64

# %%
#group by combinations:
#split #applyfunction #combining results

# %%
 country_group = df.groupby(['Country'])

# %%
 country_group #DataFrameGroupBy

# %%
 country_group.get_group('Nepal') #like a filter ##filt = df['Country'] == 'Nepal' # df.loc[filt]
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 173                 I am a developer by profession      Yes  26.0         13
# 275                 I am a developer by profession       No   NaN         18
# 623                    I code primarily as a hobby      Yes  18.0         12
# 807                 I am a developer by profession      Yes  34.0         26
# 1355                I am a developer by profession      Yes  26.0         15
# ...                                            ...      ...   ...        ...
# 64711               I am a developer by profession      Yes  19.0         16
# 65064               I am a developer by profession      Yes   NaN         17
# 65171               I am a developer by profession      Yes   NaN         20
# 65179       I am a student who is learning to code       No   NaN        NaN
# 63820                                          NaN      Yes   NaN         17
#
# ...

# %%
 country_group.get_group('Nepal')
type( country_group.get_group('Nepal'))
# Out:
# pandas.core.frame.DataFrame

# %%
d = country_group.get_group('Nepal')

# %%
c=d['CurrencyDesc'].value_counts() #currency type for survey candids of group country nepal
c
# Out:
# Nepalese rupee          118
# United States dollar     11
# Indian rupee              2
# Australian dollar         1
# Serbian dinar             1
# Name: CurrencyDesc, dtype: int64

# %%
c.median() 
d['CurrencyDesc'].value_counts(normalize=True)*100
# Out:
# Nepalese rupee          88.721805
# United States dollar     8.270677
# Indian rupee             1.503759
# Australian dollar        0.751880
# Serbian dinar            0.751880
# Name: CurrencyDesc, dtype: float64

# %%
d['Trans'].value_counts() #for nepal trans memebers of group country nepal
# Out:
# No     168
# Yes      2
# Name: Trans, dtype: int64

# %%
df['Trans'].value_counts()
# Out:
# No     48871
# Yes      474
# Name: Trans, dtype: int64

# %%
c.loc['Nepalese rupee']
# Out:
# 118

# %%
country_group = df.groupby(['Country'])
cf = 
#f=country_group.get_group('Nepal')
#cg=country_group['ConvertedComp'].agg(['median','mean','count']) #for nepal only f['ConvertedComp']............
# Out:
#   File "<ipython-input-27-f09ae52dd289>", line 2
#     cf =
#          ^
# SyntaxError: invalid syntax

# %%
cg.loc['Nepal'] #82 are from nepal

# %%
#tried myself to convert %of python users from different countries
#gh=country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
#g=pd.DataFrame(gh)
#type(g)
#g

# %%
#z=g['LanguageWorkedWith'].value_counts(normalize=True)*100
#z

# %%
##finished

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# Mali                  1
# Fiji                  1
# Liechtenstein         1
# Chad                  1
# Gabon                 1
# Name: Country, Length: 183, dtype: int64

# %%
country_uses_python=country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
python_df= pd.concat([country_respondents,country_uses_python], axis = 'columns',sort = False)
python_df
# Out:
#                 Country  LanguageWorkedWith
# United States     12469                5964
# India              8403                2670
# United Kingdom     3896                1621
# Germany            3890                1712
# Canada             2191                1011
# ...                 ...                 ...
# Mali                  1                   0
# Fiji                  1                   0
# Liechtenstein         1                   0
# Chad                  1                   0
# Gabon                 1                   1
#
# [183 rows x 2 columns]

# %%
python_df.rename(columns = {'Country': 'NumRespondents','LanguageWorkedWith':'NumKnowsPython'},inplace = True)

# %%
python_df

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']*100)

# %%
python_df.sort_values(by = 'PctKnowsPython',ascending = False,inplace = True)

# %%
python_df.head(25)
