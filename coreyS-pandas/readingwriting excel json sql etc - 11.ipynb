# %%
import pandas as pd

# %%
df= pd.read_csv('developer/survey_results_public.csv',index_col = 'Respondent')
schema_df = pd.read_csv('developer/survey_results_schema.csv',index_col='Column')

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
filt = (df['Country']=='Nepal')

# %%
cf=df.loc[filt]

# %%
cf
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 173                 I am a developer by profession      Yes  26.0         13
# 275                 I am a developer by profession       No   NaN         18
# 623                    I code primarily as a hobby      Yes  18.0         12
# 807                 I am a developer by profession      Yes  34.0         26
# 1355                I am a developer by profession      Yes  26.0         15
# ...                                            ...      ...   ...        ...
# 64711               I am a developer by profession      Yes  19.0         16
# 65064               I am a developer by profession      Yes   NaN         17
# 65171               I am a developer by profession      Yes   NaN         20
# 65179       I am a student who is learning to code       No   NaN        NaN
# 63820                                          NaN      Yes   NaN         17
#
# ...

# %%
#writing this data

# %%
cf.to_csv('modified.csv',sep = '\t') #creating csv

# %%
#excel

# %%
cf.to_excel('modified.xlsx') #creating excel

# %%
test = pd.read_excel('modified.xlsx',index_col='Respondent')

# %%
#json

# %%
cf.to_json('modified.json')

# %%
cf.to_json('modified.json',orient = 'records',lines = True)#writing json

# %%
#reading json

# %%
walla = pd.read_json('modified.json',orient = 'records',lines = True)

# %%
posts_df = pd.read_json('https://data.nepalcorona.info/api/v1/covid/timeline.json')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-47-46c05f73abab> in <module>
# ----> 1 posts_df = pd.read_json('https://data.nepalcorona.info/api/v1/covid/timeline.json')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     583     compression = infer_compression(path_or_buf, compression)
#     584     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# ...
